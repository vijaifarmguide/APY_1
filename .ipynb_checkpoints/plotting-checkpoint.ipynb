# %%
import seaborn as sns
import pandas as pd
# %matplotlib inline
# turn of warning messages
pd.options.mode.chained_assignment = None  # default='warn'

# get data
df = pd.read_csv('APY_data_simple crops.csv')
#df.head(5)


#remove numbers

# %%
def describe_dataframe(df=pd.DataFrame()):
    """This function generates descriptive stats of a dataframe
    Args:
        df (dataframe): the dataframe to be analyzed
    Returns:
        None

    """
    print("\n\n")
    print("*"*30)
    print("About the Data")
    print("*"*30)
    
    print("Number of rows::",df.shape[0])
    print("Number of columns::",df.shape[1])
    print("\n")
    
    print("Column Names::",df.columns.values.tolist())
    print("\n")
    
    print("Column Data Types::\n",df.dtypes)
    print("\n")
    
    print("Columns with Missing Values::",df.columns[df.isnull().any()].tolist())
    print("\n")
    
    print("Number of rows with Missing Values::",len(pd.isnull(df).any(1).nonzero()[0].tolist()))
    print("\n")
    
    print("Sample Indices with missing data::",pd.isnull(df).any(1).nonzero()[0].tolist()[0:5])
    print("\n")
    
    print("General Stats::")
    print(df.info())
    print("\n")
    
    print("Summary Stats::")
    print(df.describe())
    print("\n")
    
    print("Dataframe Sample Rows::")
    display(df.head(5))

# %%
# %time describe_dataframe(df)
# Out:
# ******************************
# About the Data
# ******************************
# Number of rows:: 198619
# Number of columns:: 8
#
#
# Column Names:: ['State', 'District', 'Crop', 'Year', 'Season', 'Area (Hectare)', 'Production (Tonnes)', 'Yield (Tonnes/Hectare)']
#
#
# Column Data Types::
#  State                      object
# District                   object
# Crop                       object
# Year                       object
# Season                     object
# Area (Hectare)            float64
# Production (Tonnes)       float64
# Yield (Tonnes/Hectare)    float64
# dtype: object
#
#
# Columns with Missing Values:: ['Production (Tonnes)']
#
#
# Number of rows with Missing Values:: 3014
#
#
# Sample Indices with missing data:: [570, 576, 1142, 1207, 1392]
#
#
# General Stats::
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198619 entries, 0 to 198618
# Data columns (total 8 columns):
# State                     198619 non-null object
# District                  198619 non-null object
# Crop                      198619 non-null object
# Year                      198619 non-null object
# Season                    198619 non-null object
# Area (Hectare)            198619 non-null float64
# Production (Tonnes)       195605 non-null float64
# Yield (Tonnes/Hectare)    198619 non-null float64
# dtypes: float64(3), object(5)
# memory usage: 12.1+ MB
# None
#
#
# Summary Stats::
#        Area (Hectare)  Production (Tonnes)  Yield (Tonnes/Hectare)
# count    1.986190e+05         1.956050e+05           198619.000000
# mean     1.379188e+04         5.331632e+04                4.149695
# std      5.325334e+04         4.152088e+05               14.380246
# min      4.000000e-02         0.000000e+00                0.000000
# 25%      9.700000e+01         9.400000e+01                0.500000
# 50%      7.580000e+02         7.800000e+02                0.910000
# 75%      5.897000e+03         8.000000e+03                1.870000
# max      8.580100e+06         2.004970e+07             1494.000000
#
#
# Dataframe Sample Rows::
#                          State                     District       Crop  \
# 0  Andaman and Nicobar Islands                               Arhar/Tur
# 1  Andaman and Nicobar Islands                               Arhar/Tur
# 2  Andaman and Nicobar Islands                               Arhar/Tur
# 3  Andaman and Nicobar Islands   2.NORTH AND MIDDLE ANDAMAN  Arhar/Tur
# 4  Andaman and Nicobar Islands   2.NORTH AND MIDDLE ANDAMAN  Arhar/Tur
#
#        Year       Season  Area (Hectare)  Production (Tonnes)  \
# 0   2007-08  Rabi                   24.0                129.0
# 1   2008-09  Summer                131.0                 92.0
# 2   2009-10  Summer                331.0                164.0
# 3   2010-11  Rabi                  294.5                 91.0
# 4   2011-12  Rabi                  210.0                 63.0
#
#    Yield (Tonnes/Hectare)
# 0                    5.35
# 1                    0.70
# 2                    0.50
# 3                    0.31
# 4                    0.30
# CPU times: user 349 ms, sys: 28.1 ms, total: 377 ms
# Wall time: 393 ms

# %%
df1=df[df.District!=" "]
df1['District']=df1['District'].str.replace('[^a-zA-Z ]', '')

# %%
df1.isnull().sum()
#Null values means Yield is zero
# Out:
# State                        0
# District                     0
# Crop                         0
# Year                         0
# Season                       0
# Area (Hectare)               0
# Production (Tonnes)       3014
# Yield (Tonnes/Hectare)       0
# dtype: int64

# %%
#df1[(df1.State=="Rajasthan") & (df1['Production (Tonnes)'].isnull())].shape

# %%
#df1[(df1.State=="Rajasthan") & (df1['Production (Tonnes)'].isnull())].shape

# %%
#df1[(df1.State=="Rajasthan") & (df1['Production (Tonnes)'].notnull()) & (df1['Yield (Tonnes/Hectare)']==0)]

# %%
df1[df1['Production (Tonnes)'].isnull()].shape
# Out:
# (3014, 8)

# %%
#Yield =0 ie , Production = 0
df1[df1['Production (Tonnes)'].isnull()]=0

# %%
df1[(df1['Yield (Tonnes/Hectare)']!=0) & (df1['Production (Tonnes)']==0)].shape[0]  #297
df1[(df1['Yield (Tonnes/Hectare)']==0) & (df1['Production (Tonnes)']!=0)].shape[0]  #65
df1[(df1['Yield (Tonnes/Hectare)']==0) & (df1['Production (Tonnes)']==0)].shape[0]  #3867 

#useful values
df1[(df1['Yield (Tonnes/Hectare)']!=0) & (df1['Production (Tonnes)']!=0)].shape[0]  #194168
# Out:
# 194168

# %%
df1=df1[df1['Season']!=0]

# %%
print(df1['Season'].value_counts())
#print(df['Year'].value_counts())
# Out:
# Kharif         87932
# Rabi           58088
# Whole Year     24998
# Summer         13972
# Winter          5627
# Autumn          4766
# Name: Season, dtype: int64

# %%
#take data for 2005-2015 data 
a=df['Year'].value_counts().index
a=sorted(a)
print(a)
# Out:
# [' 1997-98', ' 1998-99', ' 1999-00', ' 2000-01', ' 2001-02', ' 2002-03', ' 2003-04', ' 2004-05', ' 2005-06', ' 2006-07', ' 2007-08', ' 2008-09', ' 2009-10', ' 2010-11', ' 2011-12', ' 2012-13', ' 2013-14', ' 2014-15', ' 2015-16']

# %%
df1.columns
# Out:
# Index(['State', 'District', 'Crop', 'Year', 'Season', 'Area (Hectare)',
#        'Production (Tonnes)', 'Yield (Tonnes/Hectare)'],
#       dtype='object')

# %%
yearlist=[' 2005-06', ' 2006-07', ' 2007-08', ' 2008-09', ' 2009-10', ' 2010-11', ' 2011-12', ' 2012-13', ' 2013-14', ' 2014-15']

# %%
#df1.groupby(['State','District','Season','Crop'])['Year'].count()

# %%
#df1[df1.groupby(['State','District','Season','Crop'])['Year']==yearlist]

# %%
#d2=df1[(df1['Year']==' 2010-11') & (df1['Season']=='Kharif     ') & (df1.State=="Rajasthan") ].groupby(['State','District','Crop'],sort=False)['Area (Hectare)'].sum()
#d2.sort_index(ascending=False)

# %%
#df1['Season'].unique()
# Out:
# array(['Rabi       ', 'Whole Year ', 'Kharif     ', 'Autumn     ',
#        'Summer     ', 'Winter     '], dtype=object)

# %%
#df1['State'].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype=object)

# %%
#df2=df1[(df1['Year']==' 2010-11') & ((df1['Season']=='Kharif     ') | (df1['Season']=='Whole Year ')) & ((df1.State=="Bihar") | (df1.State=="Chhattisgarh")  | (df1.State=="Gujarat") | (df1.State=="Haryana") | (df1.State=="Madhya Pradesh") | (df1.State=="Maharashtra") | (df1.State=="Punjab") | (df1.State=="Uttar Pradesh") | (df1.State=="Rajasthan"))].sort_values(['State','District', 'Area (Hectare)'], ascending=[True,True, False])

# %%
#df3=df2[[ 'State', 'District', 'Crop', 'Season', 'Area (Hectare)' ]]
dfVisual=df1[[ 'State', 'District', 'Crop', 'Season', 'Area (Hectare)', 'Production (Tonnes)' ]]

# %%
#df3.columns
# Out:
# Index(['State', 'District', 'Crop', 'Season', 'Area (Hectare)'], dtype='object')

# %%
ax = sns.distplot(dfVisual['Area (Hectare)'],kde=True,bins=30)
ax.get_xaxis().get_major_formatter().set_scientific(False)
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#df3.head(10)
g = sns.jointplot(x='Area (Hectare)',y='Production (Tonnes)',data=df1[df1['Area (Hectare)'] ],kind='scatter')
g.ax_joint.xaxis.get_major_formatter().set_scientific(False)
g.ax_joint.yaxis.get_major_formatter().set_scientific(False)
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#df1.to_csv("sort1.csv")
#df3.shape[0]
# Out:
# 3622

# %%
#df3.groupby(['District', 'Crop'])['Area (Hectare)'].sum()
df3['TotalDistrictArea'] =  df3.groupby(['State','District'],sort=False)['Area (Hectare)'].transform('sum')

# %%
#df3
# Out:
#                 State     District                 Crop       Season  \
# 29138           Bihar       ARARIA    Moong(Green Gram)  Kharif
# 24440           Bihar       ARARIA           Horse-gram  Kharif
# 32221           Bihar       ARARIA                 Ragi  Kharif
# 36060           Bihar       ARARIA            Sugarcane  Whole Year
# 37790           Bihar       ARARIA                 Urad  Kharif
# 21938           Bihar       ARARIA            Arhar/Tur  Kharif
# 24279           Bihar       ARARIA            Groundnut  Kharif
# 21949           Bihar        ARWAL            Arhar/Tur  Kharif
# 35098           Bihar        ARWAL              Sesamum  Kharif
# 177709  Uttar Pradesh     VARANASI             Sannhamp  Kharif
# 172399  Uttar Pradesh     VARANASI    Moong(Green Gram)  Kharif
# 164460  Uttar Pradesh     VARANASI            Guar seed  Kharif
# 182903  Uttar Pradesh     VARANASI         Sweet potato  Kharif
# 163768  Uttar Pradesh     VARANASI            Groundnut  Kharif
#
#         Area (Hectare)  TotalDistrictArea
# 29138           1724.0             3906.0
# 24440           1454.0             3906.0
# 32221            267.0             3906.0
# 36060            147.0             3906.0
# 37790            146.0             3906.0
# 21938            122.0             3906.0
# 24279             46.0             3906.0
# 21949            451.0              642.0
# 35098             58.0              642.0
# 29162             43.0              642.0
# 32232             37.0              642.0
# 36067             32.0              642.0
# 37802             21.0              642.0
# 36084            895.0             1310.0
# 21968            401.0             1310.0
# 35116             11.0             1310.0
# 32251              2.0             1310.0
# 29191              1.0             1310.0
# 36101           3256.0             5532.0
# 24468            787.0             5532.0
# 21987            607.0             5532.0
# 29222            517.0             5532.0
# 30717            362.0             5532.0
# 35130              3.0             5532.0
# 36118           6256.0             8461.0
# 37845            941.0             8461.0
# 22006            601.0             8461.0
# 24481            252.0             8461.0
# 29255            140.0             8461.0
# 35651             96.0             8461.0
# ...                ...                ...
# 172330            34.0           122433.0
# 163739            18.0           122433.0
# 177682             2.0           122433.0
# 177128         81000.0           163040.0
# 169207         28135.0           163040.0
# 185552         23732.0           163040.0
# 178889         11746.0           163040.0
# 165618          4538.0           163040.0
# 172367          4327.0           163040.0
# 158724          3354.0           163040.0
# 163759          2850.0           163040.0
# 159965          1841.0           163040.0
# 181272          1030.0           163040.0
# 182891           452.0           163040.0
# 164448            30.0           163040.0
# 177696             4.0           163040.0
# 179548             1.0           163040.0
# 177154         42021.0            64753.0
# 159984          5626.0            64753.0
# 158743          4327.0            64753.0
# 181291          3972.0            64753.0
# 169255          3109.0            64753.0
# 165637          2525.0            64753.0
# 185585          1991.0            64753.0
# 178909           445.0            64753.0
# 177709           361.0            64753.0
# 172399           276.0            64753.0
# 164460            53.0            64753.0
# 182903            46.0            64753.0
# 163768             1.0            64753.0
#
# [3622 rows x 6 columns]

# %%
df3 = df3.groupby(['State','District'],sort=False).head(2).reset_index(drop=True)

# %%
#df3['TopTwoCropArea'] =  df3.groupby(['State','District'],sort=False)['Area (Hectare)'].transform('sum')

# %%
df3['TopTwoCropAreaPercent'] = df3['Area (Hectare)']/df3['TotalDistrictArea']

# %%
df3
# Out:
#              State             District               Crop       Season  \
# 0            Bihar               ARARIA  Moong(Green Gram)  Kharif
# 1            Bihar               ARARIA         Horse-gram  Kharif
# 2            Bihar                ARWAL          Arhar/Tur  Kharif
# 3            Bihar                ARWAL            Sesamum  Kharif
# 4            Bihar           AURANGABAD          Sugarcane  Whole Year
# 5            Bihar           AURANGABAD          Arhar/Tur  Kharif
# 6            Bihar                BANKA          Sugarcane  Whole Year
# 614  Uttar Pradesh            SONBHADRA              Maize  Kharif
# 615  Uttar Pradesh            SULTANPUR               Rice  Kharif
# 616  Uttar Pradesh            SULTANPUR          Sugarcane  Kharif
# 617  Uttar Pradesh                UNNAO               Rice  Kharif
# 618  Uttar Pradesh                UNNAO              Maize  Kharif
# 619  Uttar Pradesh             VARANASI               Rice  Kharif
# 620  Uttar Pradesh             VARANASI              Bajra  Kharif
#
#      Area (Hectare)  TotalDistrictArea  TopTwoCropAreaPercent
# 0            1724.0             3906.0               0.441372
# 1            1454.0             3906.0               0.372248
# 2             451.0              642.0               0.702492
# 3              58.0              642.0               0.090343
# 4             895.0             1310.0               0.683206
# 5             401.0             1310.0               0.306107
# 6            3256.0             5532.0               0.588576
# 7             787.0             5532.0               0.142263
# 8            6256.0             8461.0               0.739393
# 9             941.0             8461.0               0.111216
# 10           6607.0            12372.0               0.534028
# 11           2771.0            12372.0               0.223973
# 12           1632.0             4724.0               0.345470
# 13           1338.0             4724.0               0.283235
# 14           3371.0             5991.0               0.562677
# 15           1650.0             5991.0               0.275413
# 16           1443.0             2562.0               0.563232
# 17            719.0             2562.0               0.280640
# 18           1040.0             4570.0               0.227571
# 19            900.0             4570.0               0.196937
# 20          30872.0            32722.0               0.943463
# 21           1080.0            32722.0               0.033005
# 22           2390.0             3125.0               0.764800
# 23            607.0             3125.0               0.194240
# 24            202.0              418.0               0.483254
# 25            145.0              418.0               0.346890
# 26           1937.0             2298.0               0.842907
# 27            317.0             2298.0               0.137946
# 28           3395.0             6060.0               0.560231
# 29           1927.0             6060.0               0.317987
# ..              ...                ...                    ...
# 591        149172.0           206968.0               0.720749
# 592         56183.0           206968.0               0.271457
# 593         96664.0           124976.0               0.773461
# 594         10859.0           124976.0               0.086889
# 595         80776.0           113611.0               0.710987
# 596         10636.0           113611.0               0.093618
# 597        140906.0           170895.0               0.824518
# 598         24643.0           170895.0               0.144200
# 599        142703.0           209055.0               0.682610
# 600         54830.0           209055.0               0.262275
# 601         90035.0            99725.0               0.902833
# 602          3877.0            99725.0               0.038877
# 603         22116.0            39328.0               0.562347
# 604          9397.0            39328.0               0.238939
# 605        211075.0           284996.0               0.740624
# 606         45579.0           284996.0               0.159929
# 607         71137.0            97965.0               0.726147
# 608         16140.0            97965.0               0.164753
# 609        175157.0           180339.0               0.971265
# 610          2343.0           180339.0               0.012992
# 611        156947.0           322315.0               0.486937
# 612        120267.0           322315.0               0.373135
# 613         27442.0            69035.0               0.397509
# 614         13355.0            69035.0               0.193453
# 615         90048.0           122433.0               0.735488
# 616         10140.0           122433.0               0.082821
# 617         81000.0           163040.0               0.496811
# 618         28135.0           163040.0               0.172565
# 619         42021.0            64753.0               0.648943
# 620          5626.0            64753.0               0.086884
#
# [621 rows x 7 columns]

# %%
#df3.shape
# Out:
# (621, 7)

# %%
df3.to_csv("toptwopercent.csv")
