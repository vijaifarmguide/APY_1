# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
# turn of warning messages
pd.options.mode.chained_assignment = None  # default='warn'

# get data
df = pd.read_csv('APY_data_simple crops.csv')
#df.head(5)

# %%
def describe_dataframe(df=pd.DataFrame()):
    """This function generates descriptive stats of a dataframe
    Args:
        df (dataframe): the dataframe to be analyzed
    Returns:
        None

    """
    print("\n\n")
    print("*"*30)
    print("About the Data")
    print("*"*30)
    
    print("Number of rows::",df.shape[0])
    print("Number of columns::",df.shape[1])
    print("\n")
    
    print("Column Names::",df.columns.values.tolist())
    print("\n")
    
    print("Column Data Types::\n",df.dtypes)
    print("\n")
    
    print("Columns with Missing Values::",df.columns[df.isnull().any()].tolist())
    print("\n")
    
    print("Number of rows with Missing Values::",len(pd.isnull(df).any(1).nonzero()[0].tolist()))
    print("\n")
    
    print("Sample Indices with missing data::",pd.isnull(df).any(1).nonzero()[0].tolist()[0:5])
    print("\n")
    
    print("General Stats::")
    print(df.info())
    print("\n")
    
    print("Summary Stats::")
    print(df.describe())
    print("\n")
    
    print("Dataframe Sample Rows::")
    display(df.head(5))

# %%
# %time describe_dataframe(df)
# Out:
# ******************************
# About the Data
# ******************************
# Number of rows:: 198619
# Number of columns:: 8
#
#
# Column Names:: ['State', 'District', 'Crop', 'Year', 'Season', 'Area (Hectare)', 'Production (Tonnes)', 'Yield (Tonnes/Hectare)']
#
#
# Column Data Types::
#  State                      object
# District                   object
# Crop                       object
# Year                       object
# Season                     object
# Area (Hectare)            float64
# Production (Tonnes)       float64
# Yield (Tonnes/Hectare)    float64
# dtype: object
#
#
# Columns with Missing Values:: ['Production (Tonnes)']
#
#
# Number of rows with Missing Values:: 3014
#
#
# Sample Indices with missing data:: [570, 576, 1142, 1207, 1392]
#
#
# General Stats::
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198619 entries, 0 to 198618
# Data columns (total 8 columns):
# State                     198619 non-null object
# ...

# %%
#remove numbers
df1=df[df.District!=" "]
df1['District']=df1['District'].str.replace('[^a-zA-Z ]', '')

# %%
#Yield =0 ie , Production = 0
df1[df1['Production (Tonnes)'].isnull()]=0

# %%
df1=df1[df1['Season']!=0]

# %%
yearlist=[' 2005-06', ' 2006-07', ' 2007-08', ' 2008-09', ' 2009-10', ' 2010-11', ' 2011-12', ' 2012-13', ' 2013-14', ' 2014-15']

# %%
df.columns
# Out:
# Index(['State', 'District', 'Crop', 'Year', 'Season', 'Area (Hectare)',
#        'Production (Tonnes)', 'Yield (Tonnes/Hectare)'],
#       dtype='object')

# %%
#2010-11  --> 2010
df1.iloc[:,3]=df.iloc[:,3].str.split('-').str.get(0)

# %%
# capitalize the first letter of each word  of District
df1.iloc[:,1]=df1.iloc[:,1].str.lower().str.title()

# %%
df1.sample()
# Out:
#               State         District       Crop   Year       Season  \
# 197413  West Bengal   Medinipur East  Sugarcane   1998  Whole Year
#
#         Area (Hectare)  Production (Tonnes)  Yield (Tonnes/Hectare)
# 197413            10.0                960.0                    96.0

# %%
df2=df1[df1.State=="Rajasthan"]

# %%
filtered = df2['Area (Hectare)'][(df2['Area (Hectare)'] >= 0) & (df2['Area (Hectare)'] < 1.278250e+04)]
sns.distplot(filtered,kde=False,bins=50,hist_kws={"range": [0,1.278250e+04]})

# %%
df2.describe()
# Out:
#        Area (Hectare)  Production (Tonnes)  Yield (Tonnes/Hectare)
# count    1.272400e+04         1.272400e+04            12724.000000
# mean     2.545757e+04         2.803876e+04                3.470461
# std      7.472264e+04         8.537026e+04               12.079052
# min      1.000000e+00         0.000000e+00                0.000000
# 25%      4.500000e+01         3.775000e+01                0.420000
# 50%      7.975000e+02         7.120000e+02                0.900000
# 75%      1.278250e+04         1.056300e+04                1.670000
# max      1.133397e+06         1.095610e+06              251.000000

# %%
#area
sns.jointplot(x='Area (Hectare)',y='Yield (Tonnes/Hectare)',data=df2,kind='scatter')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195383 entries, 3 to 198618
# Data columns (total 8 columns):
# State                     195383 non-null object
# District                  195383 non-null object
# Crop                      195383 non-null object
# Year                      195383 non-null object
# Season                    195383 non-null object
# Area (Hectare)            195383 non-null float64
# Production (Tonnes)       195383 non-null float64
# Yield (Tonnes/Hectare)    195383 non-null float64
# dtypes: float64(3), object(5)
# memory usage: 13.4+ MB

# %%
df1[df1.State=='Rajasthan'].sample()
# Out:
#             State   District   Crop    Year       Season  Area (Hectare)  \
# 134153  Rajasthan   Jhalawar  Bajra  2014.0  Kharif                 25.0
#
#         Production (Tonnes)  Yield (Tonnes/Hectare)
# 134153                 27.0                    1.08

# %%
df1.Year=df1.Year.astype('int')

# %%
df3=df1.copy()
#df3=df3[(df3.State.str.contains('Rajasthan')) & (df3.District.str.contains('Tonk')) & (df3.Season.str.contains('Kharif')) & (df3.Crop=='Bajra')]
df3=df3[(df3.State.str.contains('Rajasthan'))  & (df3.Season.str.contains('Kharif')) & (df3.Crop=='Bajra')]

# %%
df3[(df3.State.str.contains('Rajasthan')) & (df3.District.str.contains('Tonk')) & (df3.Season.str.contains('Kharif'))]['Crop'].value_counts()
# Out:
# Bajra    19
# Name: Crop, dtype: int64

# %%
df3
# Out:
#             State  District   Crop  Year       Season  Area (Hectare)  \
# 133778  Rajasthan     Ajmer  Bajra  1997  Kharif              56600.0
# 133779  Rajasthan     Ajmer  Bajra  1998  Kharif              55089.0
# 133780  Rajasthan     Ajmer  Bajra  1999  Kharif              57959.0
# 133781  Rajasthan     Ajmer  Bajra  2000  Kharif              64826.0
# 133782  Rajasthan     Ajmer  Bajra  2001  Kharif              69903.0
# 133783  Rajasthan     Ajmer  Bajra  2002  Kharif              59416.0
# 133784  Rajasthan     Ajmer  Bajra  2003  Kharif              98497.0
# 133785  Rajasthan     Ajmer  Bajra  2004  Kharif              82174.0
# 133786  Rajasthan     Ajmer  Bajra  2005  Kharif              84447.0
# 133787  Rajasthan     Ajmer  Bajra  2006  Kharif              86479.0
# 133788  Rajasthan     Ajmer  Bajra  2007  Kharif              83559.0
# 133789  Rajasthan     Ajmer  Bajra  2008  Kharif              83304.0
# ...

# %%
sns.set_palette("GnBu_d")
sns.set_style('whitegrid')

# %%
df4=df1[df1.Season.str.contains('Kharif')].groupby(['State','District','Crop'])['Year'].count().reset_index()

# %%
df5=df4[df4.Year>10]

# %%
df5.head()
# Out:
#              State   District         Crop  Year
# 5   Andhra Pradesh   Adilabad    Arhar/Tur    14
# 6   Andhra Pradesh   Adilabad  Castor seed    14
# 8   Andhra Pradesh   Adilabad    Groundnut    12
# 10  Andhra Pradesh   Adilabad        Jowar    15
# 11  Andhra Pradesh   Adilabad        Maize    15

# %%
q=pd.merge(df1, df5, on=['State','District','Crop'], how='inner')

# %%
q.head()
# Out:
#             State   District       Crop  Year_x       Season  Area (Hectare)  \
# 0  Andhra Pradesh   Adilabad  Arhar/Tur    1997  Kharif              32200.0
# 1  Andhra Pradesh   Adilabad  Arhar/Tur    1998  Kharif              35900.0
# 2  Andhra Pradesh   Adilabad  Arhar/Tur    1998  Rabi                  100.0
# 3  Andhra Pradesh   Adilabad  Arhar/Tur    2000  Kharif              38996.0
# 4  Andhra Pradesh   Adilabad  Arhar/Tur    2000  Rabi                  767.0
#
#    Production (Tonnes)  Yield (Tonnes/Hectare)  Year_y
# 0               1100.0                    0.03      14
# 1              12700.0                    0.35      14
# 2                100.0                    1.00      14
# 3               9437.0                    0.24      14
# 4                186.0                    0.24      14

# %%
# More time on site, more money spent.
sns.jointplot(x='Year',y='Yield (Tonnes/Hectare)',data=df3)

# %%
sns.jointplot(x='Year',y='Production (Tonnes)',data=df3)

# %%
sns.jointplot(x='Year',y='Area (Hectare)',data=df3)

# %%
df1.columns
# Out:
# Index(['State', 'District', 'Crop', 'Year', 'Season', 'Area (Hectare)',
#        'Production (Tonnes)', 'Yield (Tonnes/Hectare)'],
#       dtype='object')

# %%
#data=df3[['Year','Yield (Tonnes/Hectare)']]
data=q[['Year_x','State', 'District', 'Crop','Yield (Tonnes/Hectare)']][(q['State']=='Rajasthan')]

# %%
data.reset_index(drop=True,inplace=True)
data.set_index('Year_x',inplace=True)

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
data
# Out:
#             State   District       Crop  Yield (Tonnes/Hectare)
# Year_x
# 1997    Rajasthan      Alwar  Arhar/Tur                    0.72
# 1998    Rajasthan      Alwar  Arhar/Tur                    1.32
# 1999    Rajasthan      Alwar  Arhar/Tur                    0.99
# 2000    Rajasthan      Alwar  Arhar/Tur                    0.96
# 2001    Rajasthan      Alwar  Arhar/Tur                    0.81
# 2002    Rajasthan      Alwar  Arhar/Tur                    0.15
# 2003    Rajasthan      Alwar  Arhar/Tur                    1.02
# 2004    Rajasthan      Alwar  Arhar/Tur                    3.45
# 2005    Rajasthan      Alwar  Arhar/Tur                    0.94
# 2006    Rajasthan      Alwar  Arhar/Tur                    0.87
# 2007    Rajasthan      Alwar  Arhar/Tur                    1.03
# 2008    Rajasthan      Alwar  Arhar/Tur                    0.84
# 2009    Rajasthan      Alwar  Arhar/Tur                    0.30
# 2010    Rajasthan      Alwar  Arhar/Tur                    0.95
# ...

# %%
plt.plot(data)

# %%
data.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
#Identifying Trends in Time Series
data.rolling(2).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
#Seasonal Patterns in Time Series Data
data.diff().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
